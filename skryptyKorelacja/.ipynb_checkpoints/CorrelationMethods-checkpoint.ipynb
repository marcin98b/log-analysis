# %% [markdown]
# Import libraries

# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr, kendalltau

# %% [markdown]
# Load data

# %%
path = "../12CPU_30RAM/10800s/allGroup/merged.csv"
df = pd.read_csv(path).dropna(inplace=False)

#timestamp remove
#df = df.iloc[:,1:]

if not "merge" in path:
    df = df.iloc[:,1:]
else:
    df = df.iloc[:,2:]

#methods.csv
if "methods" in path:
    endpoint_map = {
        'do-register': 0,
        'add-sell-offer': 1,
        'add-buy-offer': 2,
        'get-stock-data': 3,
        'add-company': 4,
        'get-stock-users-and-companies': 5

    }
    # zastosowanie mapowania na kolumnę endpointUrl
    df['endpointUrl'] = df['endpointUrl'].replace(endpoint_map)

#
if 'replicaId' in df.columns:
    df['replicaId'] = pd.factorize(df['replicaId'])[0]


# zaokrąglij dane procentowe zużycia do dwóch miejsc po przecinku
cols_to_round = [col for col in df.columns if 'memoryUsage' in col or 'cpuUsage' in col]
if cols_to_round:
    df[cols_to_round] = df[cols_to_round].round(2)

# %%
df = df.drop(["queueSizeForward"], axis=1);

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18361399 entries, 0 to 18361398
# Data columns (total 12 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   applicationTime          int64
#  1   databaseTime             int64
#  2   endpointUrl              int64
#  3   queueSizeBack            int64
#  4   st_cpuUsage              float64
#  5   st_memoryUsage           float64
#  6   trad_applicationTime     int64
#  7   trad_databaseTime        int64
#  8   trad_numberOfSellOffers  int64
#  9   trad_numberOfBuyOffers   int64
#  10  traf_cpuUsage            float64
#  11  traf_memoryUsage         float64
# dtypes: float64(4), int64(8)
# memory usage: 1.6 GB

# %% [markdown]
# Pearson correlation coefficient

# %%
df.corr(method="pearson")
# Out:
#                          applicationTime  databaseTime  endpointUrl  \
# applicationTime                 1.000000      0.985163     0.856444
# databaseTime                    0.985163      1.000000     0.870059
# endpointUrl                     0.856444      0.870059     1.000000
# queueSizeBack                  -0.205985     -0.206397    -0.240672
# st_cpuUsage                     0.156544      0.157496     0.285639
# st_memoryUsage                  0.018610      0.016516     0.028077
# trad_applicationTime           -0.143928     -0.141840    -0.244116
# trad_databaseTime              -0.140706     -0.138554    -0.240262
# trad_numberOfSellOffers        -0.163195     -0.158613    -0.276393
# trad_numberOfBuyOffers         -0.300588     -0.301077    -0.449612
# traf_cpuUsage                   0.132323      0.141210     0.269563
# traf_memoryUsage                0.033083      0.032115     0.040068
#
#                          queueSizeBack  st_cpuUsage  st_memoryUsage  \
# ...

# %%
plt.figure(figsize=(20,15))
sb.heatmap(df.corr(method="pearson"), annot=True, cmap='Greens')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,8))
sb.regplot(x='st_cpuUsage', y='queueSizeBack', data=df)
plt.title('Median Income vs Median House Value')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 plt.figure(figsize=(12,8))
# ----> 2 sb.regplot(x='st_cpuUsage', y='queueSizeBack', data=df)
#       3 plt.title('Median Income vs Median House Value')
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
#If the p-value is less than 0.05 then the correlation coefficient is statistically significant.

pearsonr(df['st_cpuUsage'], df['queueSizeBack'])

# %% [markdown]
# Spearman correlation coefficient

# %%
plt.figure(figsize=(15,15))
sb.heatmap(df.corr(method="spearman"), annot=True, cmap='Greens')
# Out:
# <AxesSubplot:>

# %%
spearmanr(df['st_cpuUsage'], df['queueSizeBack'])
# Out:
# SpearmanrResult(correlation=0.253059003668998, pvalue=0.0)

# %% [markdown]
# Kendall's Tau

# %%
plt.figure(figsize=(15,15))
sb.heatmap(df.corr(method="kendall"), annot=True, cmap='Greens')
# Out:
# C:\Users\kalon\anaconda3\lib\site-packages\scipy\stats\stats.py:4812: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
# <AxesSubplot:>

# %%
kendalltau(df['st_cpuUsage'], df['queueSizeBack'])
# Out:
# KendalltauResult(correlation=0.1438615244459391, pvalue=0.0)
